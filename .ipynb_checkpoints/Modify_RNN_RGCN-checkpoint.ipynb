# %%
from RGCN.layers import RGCNBasisLayer
import time
import ProcessData
import random
import copy
import math
import torch
from conv import GraphConv
import torch.nn as nn
import dgl
import dgl.function as fn
import torch as th
import torch.nn.functional as F
import networkx as nx
import matplotlib.pyplot as plt
from dgl import DGLGraph
from torch.autograd import Variable
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
from functools import partial
import pandas as pd
import numpy as np

# %%
#留给GPU的接口
def create_variable(tensor):
    return Variable(tensor)

# %%
class RNNEncoder(nn.Module):
    
    def __init__(self,input_size,hidden_size,output_size,n_layers=1,bidirectional=True):
        super(RNNEncoder, self).__init__()
        self.hidden_size = hidden_size
        self.n_layers = n_layers
        self.n_directions = int(bidirectional) + 1
        
        self.embedding = nn.Embedding(input_size, hidden_size)
        #self.gru = nn.GRU(hidden_size, hidden_size, n_layers,bidirectional=bidirectional)
        self.LSTM = nn.LSTM(hidden_size, hidden_size,num_layers = n_layers,bidirectional=bidirectional)
        self.fc = nn.Linear(hidden_size, output_size)
        
    
    def forward(self, input, seq_lengths):
        # Note: we run this all at once (over the whole input sequence)
        # input shape: B x S (input size)
        # transpose to make S(sequence) x B (batch)
        input = input.t()
        batch_size = input.size(1)

        # Make a hidden
        #hidden = self._init_hidden(batch_size)
        h_0 = torch.zeros(self.n_layers * self.n_directions,
                             batch_size,self.hidden_size)
        c_0 = torch.zeros(self.n_layers * self.n_directions,
                             batch_size,self.hidden_size)
        # Embedding S x B -> S x B x I (embedding size)
        #print("s*b",input.size())
        embedded = self.embedding(input.long())
        #print("s*b*i",embedded.size())
        # Pack them up nicely
        #gru_input = pack_padded_sequence(embedded, seq_lengths.data.cpu().numpy())

        # To compact weights again call flatten_parameters().
        
        #self.gru.flatten_parameters()
        #output, hidden = self.gru(embedded, hidden)
        
        self.LSTM.flatten_parameters()
        
        output, (h_n, c_n) = self.LSTM(embedded, (h_0,c_0))
        # Use the last layer output as FC's input
        # No need to unpack, since we are going to use hidden
        fc_output = self.fc(h_n[-1,:])
        return fc_output
    def _init_hidden(self,batch_size):
        hidden = torch.zeros(self.n_layers * self.n_directions,
                            batch_size,self.hidden_size)
        return create_variable(hidden)

# %%
class BaseRGCN(nn.Module):
    def __init__(self, num_nodes, h_dim, out_dim, num_rels, num_bases=-1,
                 num_hidden_layers=1, dropout=0, use_cuda=False):
        super(BaseRGCN, self).__init__()
        self.num_nodes = num_nodes
        self.h_dim = h_dim
        self.out_dim = out_dim
        self.num_rels = num_rels
        self.num_bases = num_bases
        self.num_hidden_layers = num_hidden_layers
        self.dropout = dropout
        self.use_cuda = use_cuda

        # create rgcn layers
        self.build_model()

        # create initial features
        #self.features = self.create_features()

    def build_model(self):
        self.layers = nn.ModuleList()
        # i2h
        i2h = self.build_input_layer()
        if i2h is not None:
            self.layers.append(i2h)
        # h2h
        for idx in range(self.num_hidden_layers):
            h2h = self.build_hidden_layer(idx)
            self.layers.append(h2h)
        # h2o
        h2o = self.build_output_layer()
        if h2o is not None:
            self.layers.append(h2o)

    # initialize feature for each node
    def create_features(self):
        return None

    def build_input_layer(self):
        return None

    def build_hidden_layer(self, idx):
        raise NotImplementedError

    def build_output_layer(self):
        return None

    def forward(self, g, features):
        self.features = features
        if self.features is not None:
            g.ndata['h'] = self.features
        for layer in self.layers:
            layer(g)
        return g.ndata.pop('h')

# %%
class RGCN(BaseRGCN):
    def create_features(self):
        features = torch.arange(self.num_nodes)
        if self.use_cuda:
            features = features.cuda()
        return features

    def build_input_layer(self):
        return RGCNBasisLayer(self.num_nodes, self.h_dim, self.num_rels, self.num_bases, activation=F.relu, is_input_layer=True)

    def build_hidden_layer(self, idx):
        return RGCNBasisLayer(self.h_dim, self.h_dim, self.num_rels, self.num_bases,
                         activation=F.relu)

    def build_output_layer(self):
        return RGCNBasisLayer(self.h_dim, self.out_dim, self.num_rels,self.num_bases)

# %%
def Stratified_Sampling(labels):
    def typicalSampling(group, typicalFracDict):
        name = group.name
        frac = typicalFracDict[name]
        return group.sample(frac=frac)
    df = pd.DataFrame({
                      'labels': labels})
    typicalFracDict = {}
    for key in range(max(labels)+1):
         typicalFracDict[key] = 0.8
    result = df.groupby('labels', group_keys=False).apply(typicalSampling, typicalFracDict)
    train_indx=list(result.index)
    test_indx=[]
    for i in range(len(labels)):
        if i not in train_indx:
            test_indx.append(i)
    return train_indx,test_indx

# %%
def Comput_Accuracy(index,output,labels_y):
    test_result = output[index]
    pred = test_result.data.max(1, keepdim=True)[1]
    test_target = labels_y[index]
    correct = 0
    correct += pred.eq(test_target.data.view_as(pred)).cpu().sum()
    return float(correct)/len(test_result)

# %%
def Create_Graph(g,full_name,authors_split,jconf,organization):
    g.add_nodes(len(authors_split))
    edge_type = []
    for i in range(len(authors_split)):
        for j in range(len(authors_split)):
            if jconf[i] == jconf[j]:
                g.add_edges(i,j)
                edge_type.append(0)
            
            for k in range(len(authors_split[i])):
                if  authors_split[i][k] in authors_split[j] and authors_split[i][k] != full_name:
                    #print("name: ",authors_split[i][k],"i: ",i,"j: ",j)
                    g.add_edges(i,j)
                    edge_type.append(1)
                    break;
            if organization[i] == organization[j] and organization[i] != 'null':
                g.add_edges(i,j)
                edge_type.append(2)
    return edge_type

# %%
def Create_Edge_List(full_name,authors_split,jconf,organization):
    edge_type = []
    edge_list_src = []
    edge_list_dst = []
    for i in range(len(authors_split)):
        for j in range(len(authors_split)):
            if jconf[i] == jconf[j]:
                edge_type.append(0)
                edge_list_src.append(i)
                edge_list_dst.append(j)
            for k in range(len(authors_split[i])):
                if  authors_split[i][k] in authors_split[j] and authors_split[i][k] != full_name:
                    #print("name: ",authors_split[i][k],"i: ",i,"j: ",j)
                    edge_type.append(1)
                    edge_list_src.append(i)
                    edge_list_dst.append(j)
                    break;
            if organization[i] == organization[j] and organization[i] != 'null':
                edge_list_src.append(i)
                edge_type.append(2)
                edge_list_dst.append(j)
    return edge_type,edge_list_src,edge_list_dst

# %% [markdown]
# # <b> Model

# %%
class GCN_Plus_RNN(nn.Module):
    def __init__(self,RNN_input_size,RNN_hidden_size,RGCN_input_size,RGCN_hidden_size,Num_classes,Num_rels,Num_bases=-1,Num_hidden_layers=1,dropout=0):
        super(GCN_Plus_RNN, self).__init__()
        
        self.RNN = RNNEncoder(RNN_input_size,RNN_hidden_size,RGCN_input_size)
        
        self.RGCN = RGCN(RGCN_input_size,
                         RGCN_hidden_size,
                         Num_classes,
                         Num_rels,
                         Num_bases,
                         Num_hidden_layers,
                         dropout)

        
    def forward(self, g, inputs, sequence_length):
        features = self.RNN(inputs,sequence_length)      #RNN编码

        x = self.RGCN(g,features)             
        #x = self.gcn1(g, features) 
        return x

# %% [markdown]
# # <b> 读数据

# %%
title,labels,jconf,authors,FullName,organization = ProcessData.ProcessingRawData("Data\\Jing Zhang\\Jing Zhang.xml")
title = ProcessData.Wipe_off_Punctuation(title)
title_vocab,title_split = ProcessData.Split_Title(title)
title_one_hot,Max_Sequence_Len,vocab_size = ProcessData.One_hot_encoding(title_vocab,title_split)
title_one_hot_padding = ProcessData.Padding_One_hot(title_one_hot,Max_Sequence_Len)
author_vocab,authors_split = ProcessData.Split_Authors(authors)
# len(authors_split)
# len(title_one_hot_padding)
# # vocab_size

# %% [markdown]
# # <b> 构造图

# %%
edge_type,edge_list_src,edge_list_dst = Create_Edge_List(FullName,authors_split,jconf,organization)
np.save("Data\\Jing Zhang\\edge_type.npy",edge_type)
np.save("Data\\Jing Zhang\\edge_list_src.npy",edge_list_src)
np.save("Data\\Jing Zhang\\edge_list_dst.npy",edge_list_dst)
# edge_type = np.load("Data\\LeiWang\\edge_type.npy")
# edge_list_src = np.load("Data\\LeiWang\\edge_list_src.npy")
# edge_list_dst = np.load("Data\\LeiWang\\edge_list_dst.npy")
# test_idx = np.load("Data\\LeiWang\\test_index.npy")
# train_idx = np.load("Data\\LeiWang\\train_index.npy")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-6779891e3e99> in <module>()
#       1 edge_type,edge_list_src,edge_list_dst = Create_Edge_List(FullName,authors_split,jconf,organization)
# ----> 2 np.save("Data\\Jing Zhang\\edge_type.npy",edge_type)
#       3 np.save("Data\\Jing Zhang\\edge_list_src.npy",edge_list_src)
#       4 np.save("Data\\Jing Zhang\\edge_list_dst.npy",edge_list_dst)
#       5 # edge_type = np.load("Data\\LeiWang\\edge_type.npy")
#
# NameError: name 'np' is not defined

# %%
g = dgl.DGLGraph()
g.add_nodes(len(authors_split))
g.add_edges(edge_list_src,edge_list_dst)
edge_norm = [1 for i in range(len(edge_type))]
g.edata.update({'type': torch.LongTensor(edge_type), 'norm': torch.Tensor(edge_norm)})
#edge_type = Create_Graph(g,FullName,authors_split,jconf,organization)

# %%
print("Number of edges: ",len(g.edges()[0]))
print("Number of nodes: ",len(authors_split))
print("Number of class: ",max(labels)+1)
vocab_size
# Out:
# Number of edges:  2169
# Number of nodes:  231
# Number of class:  85
# 911

# %%
y_data = labels
inputs = create_variable(torch.Tensor(title_one_hot_padding))
labels_y = create_variable(torch.LongTensor(y_data))

# %%
# train_idx = random.sample(range(len(authors_split)),264)
# test_idx = []
# for i in range(len(authors_split)):
#      if i not in training_idx:
#         test_idx.append(i)

# %%
train_idx,test_idx =Stratified_Sampling(labels)
print(len(train_idx),len(test_idx))
# Out:
# 200 31

# %%
RNN_input_size = vocab_size
RNN_hidden_size = 50
RGCN_input_size = 25
RGCN_hidden_size = 20
Num_classes = max(labels)+1
Num_rels = 3
Num_layers = 1
dropout = 0.6
activation = F.relu
sequence_length = inputs.size()[1]

# %%
def Training(Times,Name):
    
    Max_Accuracy = 0
    for i in range(Times):
        
        train_idx,test_idx =Stratified_Sampling(labels)
        model = GCN_Plus_RNN(RNN_input_size,
                         RNN_hidden_size,
                         RGCN_input_size,
                         RGCN_hidden_size,
                         Num_classes,
                         Num_rels,
                         Num_bases=-1,
                         Num_hidden_layers=0,
                         dropout=dropout)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=0)
        criterion = nn.CrossEntropyLoss()
        model.train()
        for i in range(201):
            optimizer.zero_grad()
            output = model(g, inputs, sequence_length)
            loss = criterion(output[train_idx], labels_y[train_idx])
            loss.backward()
            optimizer.step()
            
        Accuracy = Comput_Accuracy(test_idx,output,labels_y)
        print(Accuracy,Max_Accuracy,Accuracy > Max_Accuracy)
        if Accuracy > Max_Accuracy:
            Max_Accuracy = Accuracy
            np.save("Data\\David E. Goldberg\\train_index.npy",train_idx)
            np.save("Data\\David E. Goldberg\\test_index.npy",test_idx)
        print("Max_Accuracy:",Max_Accuracy)
        print("Accuracy:",Accuracy)

# %%
Training(5)
# Out:
# 0.8387096774193549 0 True
# Max_Accuracy: 0.8387096774193549
# Accuracy: 0.8387096774193549
# 0.7419354838709677 0.8387096774193549 False
# Max_Accuracy: 0.8387096774193549
# Accuracy: 0.7419354838709677
# 0.7419354838709677 0.8387096774193549 False
# Max_Accuracy: 0.8387096774193549
# Accuracy: 0.7419354838709677
# 0.8709677419354839 0.8387096774193549 True
# Max_Accuracy: 0.8709677419354839
# Accuracy: 0.8709677419354839
# 0.8064516129032258 0.8709677419354839 False
# Max_Accuracy: 0.8709677419354839
# Accuracy: 0.8064516129032258

# %%
def domodel(filename):

    xml = filename + ".xml"
    trace="Data\\"+filename+"\\"
    title,labels,jconf,authors,FullName,organization = ProcessData.ProcessingRawData(trace+xml)
    title = ProcessData.Wipe_off_Punctuation(title)
    title_vocab,title_split = ProcessData.Split_Title(title)
    title_one_hot,Max_Sequence_Len,vocab_size = ProcessData.One_hot_encoding(title_vocab,title_split)
    title_one_hot_padding = ProcessData.Padding_One_hot(title_one_hot,Max_Sequence_Len)
    author_vocab,authors_split = ProcessData.Split_Authors(authors)
    


    edge_type,edge_list_src,edge_list_dst = Create_Edge_List(FullName,authors_split,jconf,organization)
    np.save(trace+"edge_type.npy",edge_type)
    np.save(trace+"edge_list_src.npy",edge_list_src)
    np.save(trace+"edge_list_dst.npy",edge_list_dst)
    
    g = dgl.DGLGraph()
    g.add_nodes(len(authors_split))
    g.add_edges(edge_list_src,edge_list_dst)
    edge_norm = [1 for i in range(len(edge_type))]
    g.edata.update({'type': torch.LongTensor(edge_type), 'norm': torch.Tensor(edge_norm)})
    print("Number of edges: ",len(g.edges()[0]))
    print("Number of nodes: ",len(authors_split))
    print("Number of class: ",max(labels)+1)
    
    y_data = labels
    inputs = create_variable(torch.Tensor(title_one_hot_padding))
    labels_y = create_variable(torch.LongTensor(y_data))
    
    RNN_input_size = vocab_size
    RNN_hidden_size = 50
    RGCN_input_size = 25
    RGCN_hidden_size = 20
    Num_classes = max(labels)+1
    Num_rels = 3
    Num_layers = 1
    dropout = 0.6
    activation = F.relu
    sequence_length = inputs.size()[1]
    
    Max_Accuracy = 0
    for i in range(5):
        
        train_idx,test_idx =Stratified_Sampling(labels)
        if len(train_idx)==len(authors_split):
            print("sample error!")
            break;
        model = GCN_Plus_RNN(RNN_input_size,
                         RNN_hidden_size,
                         RGCN_input_size,
                         RGCN_hidden_size,
                         Num_classes,
                         Num_rels,
                         Num_bases=-1,
                         Num_hidden_layers=0,
                         dropout=dropout)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=0)
        criterion = nn.CrossEntropyLoss()
        model.train()
        for i in range(201):
            optimizer.zero_grad()
            output = model(g, inputs, sequence_length)
            loss = criterion(output[train_idx], labels_y[train_idx])
            loss.backward()
            optimizer.step()
            
        Accuracy = Comput_Accuracy(test_idx,output,labels_y)
        print(Accuracy,Max_Accuracy,Accuracy > Max_Accuracy)
        if Accuracy > Max_Accuracy:
            Max_Accuracy = Accuracy
            np.save(trace+"train_index.npy",train_idx)
            np.save(trace+"test_index.npy",test_idx)
        print("Max_Accuracy:",Max_Accuracy)
        print("Accuracy:",Accuracy)
        if Max_Accuracy == 1:
            break

# %%
names
# Out:
# ['Ajay Gupta',
#  'Alok Gupta',
#  'Barry Wilkinson',
#  'Bin Li',
#  'Bin Yu',
#  'Bin Zhu',
#  'Bing Liu',
#  'Bo Liu',
#  'Bob Johnson',
#  'Charles Smith',
#  'Cheng Chang',
#  'Daniel Massey',
#  'David Brown',
#  'David C. Wilson',
#  'David Cooper',
#  'David E. Goldberg',
#  'David Jensen',
#  'David Levine',
#  'David Nelson',
#  'Eric Martin',
#  'F. Wang',
#  'Fan Wang',
#  'Fei Su',
#  'Feng Liu',
#  'Feng Pan',
#  'Frank Mueller',
#  'Gang Chen',
#  'Gang Luo',
#  'Hao Wang',
#  'Hiroshi Tanaka',
#  'Hong Xie',
#  'Hui Fang',
#  'Hui Yu',
#  'J. Guo',
#  'J. Yin',
#  'Jeffrey Parsons',
#  'Ji Zhang',
#  'Jianping Wang',
#  'Jie Tang',
#  'Jie Yu',
#  'Jim Gray',
#  'Jing Zhang',
#  'John Collins',
#  'John F. McDonald',
#  'John Hale',
#  'Jose M. Garcia',
#  'Juan Carlos Lopez',
#  'Kai Tang',
#  'Kai Zhang',
#  'Ke Chen',
#  'Keith Edwards',
#  'Koichi Furukawa',
#  'Kuo Zhang',
#  'Lei Chen',
#  'Lei Fang',
#  'Lei Jin',
#  'Lei Wang',
#  'Li Shen',
#  'Lu Liu',
#  'M. Rahman',
#  'Manuel Silva',
#  'Mark Davis',
#  'Michael Lang',
#  'Michael Siegel',
#  'Michael Smith',
#  'Michael Wagner',
#  'Ning Zhang',
#  'Paul Brown',
#  'Paul Wang',
#  'Peter Phillips',
#  'Philip J. Smith',
#  'Ping Zhou',
#  'Qiang shen',
#  'R. Balasubramanian',
#  'R. Cole',
#  'R. Ramesh',
#  'Rafael Alonso',
#  'Rakesh Kumar',
#  'Richard Taylor',
#  'Robert Allen',
#  'Robert Schreiber',
#  'S. Huang',
#  'Sanjay Jain',
#  'Satoshi Kobayashi',
#  'Shu lin',
#  'Steve King',
#  'Thomas D. Taylor',
#  'Thomas Hermann',
#  'Thomas Meyer',
#  'Thomas Tran',
#  'Thomas Wolf',
#  'Thomas Zimmermann',
#  'Wei Wang',
#  'Wei Xu',
#  'Wen Gao',
#  'William H. Hsu',
#  'X. Zhang',
#  'Xiaoming Wang',
#  'Xiaoyan Li',
#  'Yan Tang',
#  'Yang Wang',
#  'Yang Yu',
#  'Yi Deng',
#  'Yong Chen',
#  'Yoshio Tanaka',
#  'Young Park',
#  'Yu Zhang',
#  'Yue Zhao',
#  'Yun Wang',
#  'Z. Wang']

# %%
for name in names:
    print(name)
    domodel(name)
    print("\n\n")
# Out:
# Ajay Gupta
# Number of edges:  221
# Number of nodes:  36
# Number of class:  9
# d:\Anaconda3\lib\site-packages\dgl\frame.py:204: UserWarning: Initializer is not set. Use zero initializer instead. To suppress this warning, use `set_initializer` to explicitly specify which initializer to use.
#   dgl_warning('Initializer is not set. Use zero initializer instead.'
# 0.8333333333333334 0 True
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
# 0.8333333333333334 0.8333333333333334 False
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
# 0.8333333333333334 0.8333333333333334 False
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
# 0.8333333333333334 0.8333333333333334 False
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
# 0.5 0.8333333333333334 False
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.5
#
#
#
# Alok Gupta
# Number of edges:  532
# Number of nodes:  57
# Number of class:  2
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 0.9090909090909091 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.9090909090909091
# 0.9090909090909091 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.9090909090909091
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Barry Wilkinson
# Number of edges:  163
# Number of nodes:  28
# Number of class:  1
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Bin Li
# Number of edges:  1854
# Number of nodes:  181
# Number of class:  60
# 0.8709677419354839 0 True
# Max_Accuracy: 0.8709677419354839
# Accuracy: 0.8709677419354839
# 0.8709677419354839 0.8709677419354839 False
# Max_Accuracy: 0.8709677419354839
# Accuracy: 0.8709677419354839
# 0.8709677419354839 0.8709677419354839 False
# Max_Accuracy: 0.8709677419354839
# Accuracy: 0.8709677419354839
# 0.8064516129032258 0.8709677419354839 False
# Max_Accuracy: 0.8709677419354839
# Accuracy: 0.8064516129032258
# 0.8709677419354839 0.8709677419354839 False
# Max_Accuracy: 0.8709677419354839
# Accuracy: 0.8709677419354839
#
#
#
# Bin Yu
# Number of edges:  956
# Number of nodes:  105
# Number of class:  17
# 0.8235294117647058 0 True
# Max_Accuracy: 0.8235294117647058
# Accuracy: 0.8235294117647058
# 0.8235294117647058 0.8235294117647058 False
# Max_Accuracy: 0.8235294117647058
# Accuracy: 0.8235294117647058
# 1.0 0.8235294117647058 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 0.8235294117647058 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.8235294117647058
# 0.8823529411764706 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.8823529411764706
#
#
#
# Bin Zhu
# Number of edges:  365
# Number of nodes:  46
# Number of class:  15
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 0.8571428571428571 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.8571428571428571
# 0.8571428571428571 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.8571428571428571
# 0.8571428571428571 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.8571428571428571
# 0.8571428571428571 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.8571428571428571
#
#
#
# Bing Liu
# Number of edges:  2764
# Number of nodes:  182
# Number of class:  18
# 0.9705882352941176 0 True
# Max_Accuracy: 0.9705882352941176
# Accuracy: 0.9705882352941176
# 0.9705882352941176 0.9705882352941176 False
# Max_Accuracy: 0.9705882352941176
# Accuracy: 0.9705882352941176
# 0.8823529411764706 0.9705882352941176 False
# Max_Accuracy: 0.9705882352941176
# Accuracy: 0.8823529411764706
# 0.9705882352941176 0.9705882352941176 False
# Max_Accuracy: 0.9705882352941176
# Accuracy: 0.9705882352941176
# 0.8529411764705882 0.9705882352941176 False
# Max_Accuracy: 0.9705882352941176
# Accuracy: 0.8529411764705882
#
#
#
# Bo Liu
# Number of edges:  805
# Number of nodes:  124
# Number of class:  47
# 0.9444444444444444 0 True
# Max_Accuracy: 0.9444444444444444
# Accuracy: 0.9444444444444444
# 0.8888888888888888 0.9444444444444444 False
# Max_Accuracy: 0.9444444444444444
# Accuracy: 0.8888888888888888
# 0.8888888888888888 0.9444444444444444 False
# Max_Accuracy: 0.9444444444444444
# Accuracy: 0.8888888888888888
# 1.0 0.9444444444444444 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 0.8888888888888888 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.8888888888888888
#
#
#
# Bob Johnson
# Number of edges:  28
# Number of nodes:  11
# Number of class:  7
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Charles Smith
# Number of edges:  23
# Number of nodes:  7
# Number of class:  4
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Cheng Chang
# Number of edges:  213
# Number of nodes:  27
# Number of class:  5
# 0.8 0 True
# Max_Accuracy: 0.8
# Accuracy: 0.8
# 0.8 0.8 False
# Max_Accuracy: 0.8
# Accuracy: 0.8
# 0.8 0.8 False
# Max_Accuracy: 0.8
# Accuracy: 0.8
# 0.8 0.8 False
# Max_Accuracy: 0.8
# Accuracy: 0.8
# 0.6 0.8 False
# Max_Accuracy: 0.8
# Accuracy: 0.6
#
#
#
# Daniel Massey
# Number of edges:  1297
# Number of nodes:  43
# Number of class:  2
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# David Brown
# Number of edges:  629
# Number of nodes:  61
# Number of class:  25
# 0.875 0 True
# Max_Accuracy: 0.875
# Accuracy: 0.875
# 0.75 0.875 False
# Max_Accuracy: 0.875
# Accuracy: 0.75
# 0.75 0.875 False
# Max_Accuracy: 0.875
# Accuracy: 0.75
# 0.75 0.875 False
# Max_Accuracy: 0.875
# Accuracy: 0.75
# 0.875 0.875 False
# Max_Accuracy: 0.875
# Accuracy: 0.875
#
#
#
# David C. Wilson
# Number of edges:  1128
# Number of nodes:  65
# Number of class:  5
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 0.9166666666666666 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.9166666666666666
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 0.9166666666666666 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.9166666666666666
#
#
#
# David Cooper
# Number of edges:  100
# Number of nodes:  18
# Number of class:  7
# 0.3333333333333333 0 True
# Max_Accuracy: 0.3333333333333333
# Accuracy: 0.3333333333333333
# 1.0 0.3333333333333333 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 0.6666666666666666 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.6666666666666666
#
#
#
# David E. Goldberg
# Number of edges:  14790
# Number of nodes:  231
# Number of class:  3
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 0.9782608695652174 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.9782608695652174
# 0.9565217391304348 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.9565217391304348
#
#
#
# David Jensen
# Number of edges:  646
# Number of nodes:  53
# Number of class:  4
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 0.8 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.8
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 0.9 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.9
#
#
#
# David Levine
# Number of edges:  298
# Number of nodes:  48
# Number of class:  18
# 0.7142857142857143 0 True
# Max_Accuracy: 0.7142857142857143
# Accuracy: 0.7142857142857143
# 0.7142857142857143 0.7142857142857143 False
# Max_Accuracy: 0.7142857142857143
# Accuracy: 0.7142857142857143
# 0.7142857142857143 0.7142857142857143 False
# Max_Accuracy: 0.7142857142857143
# Accuracy: 0.7142857142857143
# 0.7142857142857143 0.7142857142857143 False
# Max_Accuracy: 0.7142857142857143
# Accuracy: 0.7142857142857143
# 0.7142857142857143 0.7142857142857143 False
# Max_Accuracy: 0.7142857142857143
# Accuracy: 0.7142857142857143
#
#
#
# David Nelson
# Number of edges:  75
# Number of nodes:  20
# Number of class:  11
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
# 0.5 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.5
# 0.5 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 0.5
# 1.0 1.0 False
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Eric Martin
# Number of edges:  7347
# Number of nodes:  85
# Number of class:  5
# 0.625 0 True
# Max_Accuracy: 0.625
# Accuracy: 0.625
# 0.0 0.625 False
# Max_Accuracy: 0.625
# Accuracy: 0.0
# 0.625 0.625 False
# Max_Accuracy: 0.625
# Accuracy: 0.625
# 0.625 0.625 False
# Max_Accuracy: 0.625
# Accuracy: 0.625
# 0.6875 0.625 True
# Max_Accuracy: 0.6875
# Accuracy: 0.6875
#
#
#
# F. Wang
# Number of edges:  51
# Number of nodes:  19
# Number of class:  17
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-287-b5ba06226e99> in <module>()
#       1 for name in names:
#       2     print(name)
# ----> 3     domodel(name)
#       4     print("\n\n")
#
# <ipython-input-286-3065d71482f4> in domodel(filename)
#      52             optimizer.step()
#      53
# ---> 54         Accuracy = Comput_Accuracy(test_idx,output,labels_y)
#      55         print(Accuracy,Max_Accuracy,Accuracy > Max_Accuracy)
#      56         if Accuracy > Max_Accuracy:
#
# <ipython-input-225-f975ff3fac43> in Comput_Accuracy(index, output, labels_y)
#       1 def Comput_Accuracy(index,output,labels_y):
#       2     test_result = output[index]
# ----> 3     pred = test_result.data.max(1, keepdim=True)[1]
#       4     test_target = labels_y[index]
#       5     correct = 0
#
# RuntimeError: cannot perform reduction function max on tensor with no elements because the operation does not have an identity

# %%
#'F. Wang',
names1=['F. Wang',
 'Fan Wang',
 'Fei Su',
 'Feng Liu',
 'Feng Pan',
 'Frank Mueller',
 'Gang Chen',
 'Gang Luo',
 'Hao Wang',
 'Hiroshi Tanaka',
 'Hong Xie',
 'Hui Fang',
 'Hui Yu',
 'J. Guo',
 'J. Yin',
 'Jeffrey Parsons',
 'Ji Zhang',
 'Jianping Wang',
 'Jie Tang',
 'Jie Yu',
 'Jim Gray',
 'Jing Zhang',
 'John Collins',
 'John F. McDonald',
 'John Hale',
 'Jose M. Garcia',
 'Juan Carlos Lopez',
 'Kai Tang',
 'Kai Zhang',
 'Ke Chen',
 'Keith Edwards',
 'Koichi Furukawa',
 'Kuo Zhang',
 'Lei Chen',
 'Lei Fang',
 'Lei Jin',
 'Lei Wang',
 'Li Shen',
 'Lu Liu',
 'M. Rahman',
 'Manuel Silva',
 'Mark Davis',
 'Michael Lang',
 'Michael Siegel',
 'Michael Smith',
 'Michael Wagner',
 'Ning Zhang',
 'Paul Brown',
 'Paul Wang',
 'Peter Phillips',
 'Philip J. Smith',
 'Ping Zhou',
 'Qiang shen',
 'R. Balasubramanian',
 'R. Cole',
 'R. Ramesh',
 'Rafael Alonso',
 'Rakesh Kumar',
 'Richard Taylor',
 'Robert Allen',
 'Robert Schreiber',
 'S. Huang',
 'Sanjay Jain',
 'Satoshi Kobayashi',
 'Shu lin',
 'Steve King',
 'Thomas D. Taylor',
 'Thomas Hermann',
 'Thomas Meyer',
 'Thomas Tran',
 'Thomas Wolf',
 'Thomas Zimmermann',
 'Wei Wang',
 'Wei Xu',
 'Wen Gao',
 'William H. Hsu',
 'X. Zhang',
 'Xiaoming Wang',
 'Xiaoyan Li',
 'Yan Tang',
 'Yang Wang',
 'Yang Yu',
 'Yi Deng',
 'Yong Chen',
 'Yoshio Tanaka',
 'Young Park',
 'Yu Zhang',
 'Yue Zhao',
 'Yun Wang',
 'Z. Wang']

# %%
for name in names1:
    print(name)
    domodel(name)
    print("\n\n")
# Out:
# F. Wang
# Number of edges:  51
# Number of nodes:  19
# Number of class:  17
# sample error!
#
#
#
# Fan Wang
# Number of edges:  596
# Number of nodes:  56
# Number of class:  14
# d:\Anaconda3\lib\site-packages\dgl\frame.py:204: UserWarning: Initializer is not set. Use zero initializer instead. To suppress this warning, use `set_initializer` to explicitly specify which initializer to use.
#   dgl_warning('Initializer is not set. Use zero initializer instead.'
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Fei Su
# Number of edges:  794
# Number of nodes:  37
# Number of class:  4
# 0.8571428571428571 0 True
# Max_Accuracy: 0.8571428571428571
# Accuracy: 0.8571428571428571
# 1.0 0.8571428571428571 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Feng Liu
# Number of edges:  1133
# Number of nodes:  149
# Number of class:  32
# 0.6296296296296297 0 True
# Max_Accuracy: 0.6296296296296297
# Accuracy: 0.6296296296296297
# 0.7037037037037037 0.6296296296296297 True
# Max_Accuracy: 0.7037037037037037
# Accuracy: 0.7037037037037037
# 0.6666666666666666 0.7037037037037037 False
# Max_Accuracy: 0.7037037037037037
# Accuracy: 0.6666666666666666
# 0.7407407407407407 0.7037037037037037 True
# Max_Accuracy: 0.7407407407407407
# Accuracy: 0.7407407407407407
# 0.5925925925925926 0.7407407407407407 False
# Max_Accuracy: 0.7407407407407407
# Accuracy: 0.5925925925925926
#
#
#
# Feng Pan
# Number of edges:  748
# Number of nodes:  73
# Number of class:  15
# 0.75 0 True
# Max_Accuracy: 0.75
# Accuracy: 0.75
# 0.8333333333333334 0.75 True
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
# 0.5 0.8333333333333334 False
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.5
# 0.8333333333333334 0.8333333333333334 False
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
# 0.6666666666666666 0.8333333333333334 False
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.6666666666666666
#
#
#
# Frank Mueller
# Number of edges:  1722
# Number of nodes:  101
# Number of class:  3
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Gang Chen
# Number of edges:  3776
# Number of nodes:  178
# Number of class:  47
# 0.8275862068965517 0 True
# Max_Accuracy: 0.8275862068965517
# Accuracy: 0.8275862068965517
# 0.8620689655172413 0.8275862068965517 True
# Max_Accuracy: 0.8620689655172413
# Accuracy: 0.8620689655172413
# 0.896551724137931 0.8620689655172413 True
# Max_Accuracy: 0.896551724137931
# Accuracy: 0.896551724137931
# 0.8275862068965517 0.896551724137931 False
# Max_Accuracy: 0.896551724137931
# Accuracy: 0.8275862068965517
# 0.7586206896551724 0.896551724137931 False
# Max_Accuracy: 0.896551724137931
# Accuracy: 0.7586206896551724
#
#
#
# Gang Luo
# Number of edges:  463
# Number of nodes:  47
# Number of class:  9
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Hao Wang
# Number of edges:  1502
# Number of nodes:  178
# Number of class:  48
# 0.6333333333333333 0 True
# Max_Accuracy: 0.6333333333333333
# Accuracy: 0.6333333333333333
# 0.8 0.6333333333333333 True
# Max_Accuracy: 0.8
# Accuracy: 0.8
# 0.7666666666666667 0.8 False
# Max_Accuracy: 0.8
# Accuracy: 0.7666666666666667
# 0.8333333333333334 0.8 True
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
# 0.9 0.8333333333333334 True
# Max_Accuracy: 0.9
# Accuracy: 0.9
#
#
#
# Hiroshi Tanaka
# Number of edges:  387
# Number of nodes:  40
# Number of class:  7
# 0.8571428571428571 0 True
# Max_Accuracy: 0.8571428571428571
# Accuracy: 0.8571428571428571
# 1.0 0.8571428571428571 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Hong Xie
# Number of edges:  34
# Number of nodes:  12
# Number of class:  7
# 0.0 0 False
# Max_Accuracy: 0
# Accuracy: 0.0
# 0.0 0 False
# Max_Accuracy: 0
# Accuracy: 0.0
# 0.0 0 False
# Max_Accuracy: 0
# Accuracy: 0.0
# 0.0 0 False
# Max_Accuracy: 0
# Accuracy: 0.0
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Hui Fang
# Number of edges:  450
# Number of nodes:  42
# Number of class:  8
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Hui Yu
# Number of edges:  130
# Number of nodes:  32
# Number of class:  21
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# J. Guo
# Number of edges:  42
# Number of nodes:  13
# Number of class:  10
# sample error!
#
#
#
# J. Yin
# Number of edges:  110
# Number of nodes:  18
# Number of class:  7
# 0.6666666666666666 0 True
# Max_Accuracy: 0.6666666666666666
# Accuracy: 0.6666666666666666
# 0.6666666666666666 0.6666666666666666 False
# Max_Accuracy: 0.6666666666666666
# Accuracy: 0.6666666666666666
# 1.0 0.6666666666666666 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Jeffrey Parsons
# Number of edges:  219
# Number of nodes:  31
# Number of class:  2
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Ji Zhang
# Number of edges:  508
# Number of nodes:  64
# Number of class:  16
# 0.8181818181818182 0 True
# Max_Accuracy: 0.8181818181818182
# Accuracy: 0.8181818181818182
# 0.9090909090909091 0.8181818181818182 True
# Max_Accuracy: 0.9090909090909091
# Accuracy: 0.9090909090909091
# 0.8181818181818182 0.9090909090909091 False
# Max_Accuracy: 0.9090909090909091
# Accuracy: 0.8181818181818182
# 0.7272727272727273 0.9090909090909091 False
# Max_Accuracy: 0.9090909090909091
# Accuracy: 0.7272727272727273
# 0.9090909090909091 0.9090909090909091 False
# Max_Accuracy: 0.9090909090909091
# Accuracy: 0.9090909090909091
#
#
#
# Jianping Wang
# Number of edges:  342
# Number of nodes:  37
# Number of class:  5
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Jie Tang
# Number of edges:  1783
# Number of nodes:  66
# Number of class:  6
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Jie Yu
# Number of edges:  349
# Number of nodes:  32
# Number of class:  9
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Jim Gray
# Number of edges:  6282
# Number of nodes:  192
# Number of class:  6
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Jing Zhang
# Number of edges:  2169
# Number of nodes:  231
# Number of class:  85
# 0.8387096774193549 0 True
# Max_Accuracy: 0.8387096774193549
# Accuracy: 0.8387096774193549
# 0.8387096774193549 0.8387096774193549 False
# Max_Accuracy: 0.8387096774193549
# Accuracy: 0.8387096774193549
# 0.8387096774193549 0.8387096774193549 False
# Max_Accuracy: 0.8387096774193549
# Accuracy: 0.8387096774193549
# 0.8064516129032258 0.8387096774193549 False
# Max_Accuracy: 0.8387096774193549
# Accuracy: 0.8064516129032258
# 0.7741935483870968 0.8387096774193549 False
# Max_Accuracy: 0.8387096774193549
# Accuracy: 0.7741935483870968
#
#
#
# John Collins
# Number of edges:  483
# Number of nodes:  27
# Number of class:  7
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# John F. McDonald
# Number of edges:  789
# Number of nodes:  34
# Number of class:  2
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# John Hale
# Number of edges:  560
# Number of nodes:  39
# Number of class:  4
# 0.75 0 True
# Max_Accuracy: 0.75
# Accuracy: 0.75
# 0.875 0.75 True
# Max_Accuracy: 0.875
# Accuracy: 0.875
# 0.875 0.875 False
# Max_Accuracy: 0.875
# Accuracy: 0.875
# 0.625 0.875 False
# Max_Accuracy: 0.875
# Accuracy: 0.625
# 0.75 0.875 False
# Max_Accuracy: 0.875
# Accuracy: 0.75
#
#
#
# Jose M. Garcia
# Number of edges:  6731
# Number of nodes:  83
# Number of class:  2
# 0.0 0 False
# Max_Accuracy: 0
# Accuracy: 0.0
# 0.9375 0 True
# Max_Accuracy: 0.9375
# Accuracy: 0.9375
# 0.9375 0.9375 False
# Max_Accuracy: 0.9375
# Accuracy: 0.9375
# 0.9375 0.9375 False
# Max_Accuracy: 0.9375
# Accuracy: 0.9375
# 0.9375 0.9375 False
# Max_Accuracy: 0.9375
# Accuracy: 0.9375
#
#
#
# Juan Carlos Lopez
# Number of edges:  648
# Number of nodes:  36
# Number of class:  1
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Kai Tang
# Number of edges:  749
# Number of nodes:  48
# Number of class:  3
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Kai Zhang
# Number of edges:  455
# Number of nodes:  66
# Number of class:  24
# 0.8 0 True
# Max_Accuracy: 0.8
# Accuracy: 0.8
# 0.9 0.8 True
# Max_Accuracy: 0.9
# Accuracy: 0.9
# 0.8 0.9 False
# Max_Accuracy: 0.9
# Accuracy: 0.8
# 1.0 0.9 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Ke Chen
# Number of edges:  971
# Number of nodes:  107
# Number of class:  16
# 0.75 0 True
# Max_Accuracy: 0.75
# Accuracy: 0.75
# 0.9 0.75 True
# Max_Accuracy: 0.9
# Accuracy: 0.9
# 0.95 0.9 True
# Max_Accuracy: 0.95
# Accuracy: 0.95
# 0.85 0.95 False
# Max_Accuracy: 0.95
# Accuracy: 0.85
# 0.8 0.95 False
# Max_Accuracy: 0.95
# Accuracy: 0.8
#
#
#
# Keith Edwards
# Number of edges:  111
# Number of nodes:  23
# Number of class:  4
# 0.8 0 True
# Max_Accuracy: 0.8
# Accuracy: 0.8
# 0.8 0.8 False
# Max_Accuracy: 0.8
# Accuracy: 0.8
# 0.8 0.8 False
# Max_Accuracy: 0.8
# Accuracy: 0.8
# 0.6 0.8 False
# Max_Accuracy: 0.8
# Accuracy: 0.6
# 1.0 0.8 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Koichi Furukawa
# Number of edges:  717
# Number of nodes:  77
# Number of class:  2
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Kuo Zhang
# Number of edges:  89
# Number of nodes:  16
# Number of class:  4
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Lei Chen
# Number of edges:  2512
# Number of nodes:  196
# Number of class:  40
# 0.9090909090909091 0 True
# Max_Accuracy: 0.9090909090909091
# Accuracy: 0.9090909090909091
# 0.7878787878787878 0.9090909090909091 False
# Max_Accuracy: 0.9090909090909091
# Accuracy: 0.7878787878787878
# 0.9393939393939394 0.9090909090909091 True
# Max_Accuracy: 0.9393939393939394
# Accuracy: 0.9393939393939394
# 0.9090909090909091 0.9393939393939394 False
# Max_Accuracy: 0.9393939393939394
# Accuracy: 0.9090909090909091
# 0.9393939393939394 0.9393939393939394 False
# Max_Accuracy: 0.9393939393939394
# Accuracy: 0.9393939393939394
#
#
#
# Lei Fang
# Number of edges:  88
# Number of nodes:  17
# Number of class:  7
# 0.6666666666666666 0 True
# Max_Accuracy: 0.6666666666666666
# Accuracy: 0.6666666666666666
# 1.0 0.6666666666666666 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Lei Jin
# Number of edges:  128
# Number of nodes:  16
# Number of class:  6
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Lei Wang
# Number of edges:  2987
# Number of nodes:  308
# Number of class:  112
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-302-cb8b1bd818b7> in <module>()
#       1 for name in names1:
#       2     print(name)
# ----> 3     domodel(name)
#       4     print("\n\n")
#
# <ipython-input-300-eebe31ed8540> in domodel(filename)
#      50         for i in range(201):
#      51             optimizer.zero_grad()
# ---> 52             output = model(g, inputs, sequence_length)
#      53             loss = criterion(output[train_idx], labels_y[train_idx])
#      54             loss.backward()
#
# d:\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-7-00ec24c9ff43> in forward(self, g, inputs, sequence_length)
#      15
#      16     def forward(self, g, inputs, sequence_length):
# ---> 17         features = self.RNN(inputs,sequence_length)      #RNN编码
#      18
#      19         x = self.RGCN(g,features)
#
# d:\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-4-21e2b1d06019> in forward(self, input, seq_lengths)
#      28         # Embedding S x B -> S x B x I (embedding size)
#      29         #print("s*b",input.size())
# ---> 30         embedded = self.embedding(input.long())
#      31         #print("s*b*i",embedded.size())
#      32         # Pack them up nicely
#
# d:\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# d:\Anaconda3\lib\site-packages\torch\nn\modules\sparse.py in forward(self, input)
#     116         return F.embedding(
#     117             input, self.weight, self.padding_idx, self.max_norm,
# --> 118             self.norm_type, self.scale_grad_by_freq, self.sparse)
#     119
#     120     def extra_repr(self):
#
# d:\Anaconda3\lib\site-packages\torch\nn\functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    1452         # remove once script supports set_grad_enabled
#    1453         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 1454     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    1455
#    1456
#
# RuntimeError: index out of range at c:\a\w\1\s\tmp_conda_3.6_184213\conda\conda-bld\pytorch_1549565089053\work\aten\src\th\generic/THTensorEvenMoreMath.cpp:191

# %% [raw]
# import os
#
# def file_name(file_dir):
#     for root, dirs, files in os.walk(file_dir):
#         return files
# names = file_name("D:\\data")
# names = [i.replace('.xml', '') for i in names]
# for name in names:
#
#     os.makedirs("D:\\datas\\"+name)
# import os,shutil
#
# def mymovefile(srcfile,dstfile):
#     if not os.path.isfile(srcfile):
#         return
#     else:
#         fpath,fname=os.path.split(dstfile)    #分离文件名和路径
#         if not os.path.exists(fpath):
#             os.makedirs(fpath)                #创建路径
#         shutil.move(srcfile,dstfile)          #移动文件
# names = file_name("D:\\data")
# names = [i.replace('.xml', '') for i in names]
# for name in names:
#     srcfile = "D:\\data\\"+name+".xml"
#     dstfile = "D:\\datas\\"+name+"\\"+name+".xml"
#     mymovefile(srcfile,dstfile)
# for name in names:
#     f=open("D:\\datas\\"+name+"\\"+name+".xml",'r',encoding='utf-8')
#     os.makedirs("D:\\data\\"+name+"\\")
#     f_new=open("D:\\data\\"+name+"\\"+name+".xml",'w',encoding='utf-8')
#     lines=f.readlines() #整行读取
#     f.close()
#     for line in lines:
#         if "&" in line:
#             line=line.replace('&',' and ')
#             # 如果不符合就正常的将文件中的内容读取并且输出到新文件中
#         f_new.write(line)

# %%
names2=['Lei Wang',
 'Li Shen',
 'Lu Liu',
 'M. Rahman',
 'Manuel Silva',
 'Mark Davis',
 'Michael Lang',
 'Michael Siegel',
 'Michael Smith',
 'Michael Wagner',
 'Ning Zhang',
 'Paul Brown',
 'Paul Wang',
 'Peter Phillips',
 'Philip J. Smith',
 'Ping Zhou',
 'Qiang shen',
 'R. Balasubramanian',
 'R. Cole',
 'R. Ramesh',
 'Rafael Alonso',
 'Rakesh Kumar',
 'Richard Taylor',
 'Robert Allen',
 'Robert Schreiber',
 'S. Huang',
 'Sanjay Jain',
 'Satoshi Kobayashi',
 'Shu lin',
 'Steve King',
 'Thomas D. Taylor',
 'Thomas Hermann',
 'Thomas Meyer',
 'Thomas Tran',
 'Thomas Wolf',
 'Thomas Zimmermann',
 'Wei Wang',
 'Wei Xu',
 'Wen Gao',
 'William H. Hsu',
 'X. Zhang',
 'Xiaoming Wang',
 'Xiaoyan Li',
 'Yan Tang',
 'Yang Wang',
 'Yang Yu',
 'Yi Deng',
 'Yong Chen',
 'Yoshio Tanaka',
 'Young Park',
 'Yu Zhang',
 'Yue Zhao',
 'Yun Wang',
 'Z. Wang']

# %%
for name in names2:
    print(name)
    domodel(name)
    print("\n\n")
# Out:
# Lei Wang
# Number of edges:  2987
# Number of nodes:  308
# Number of class:  112
# d:\Anaconda3\lib\site-packages\dgl\frame.py:204: UserWarning: Initializer is not set. Use zero initializer instead. To suppress this warning, use `set_initializer` to explicitly specify which initializer to use.
#   dgl_warning('Initializer is not set. Use zero initializer instead.'
# 0.7045454545454546 0 True
# Max_Accuracy: 0.7045454545454546
# Accuracy: 0.7045454545454546
# 0.7272727272727273 0.7045454545454546 True
# Max_Accuracy: 0.7272727272727273
# Accuracy: 0.7272727272727273
# 0.6818181818181818 0.7272727272727273 False
# Max_Accuracy: 0.7272727272727273
# Accuracy: 0.6818181818181818
# 0.7727272727272727 0.7272727272727273 True
# Max_Accuracy: 0.7727272727272727
# Accuracy: 0.7727272727272727
# 0.75 0.7727272727272727 False
# Max_Accuracy: 0.7727272727272727
# Accuracy: 0.75
#
#
#
# Li Shen
# Number of edges:  749
# Number of nodes:  68
# Number of class:  9
# 0.8333333333333334 0 True
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
# 0.8333333333333334 0.8333333333333334 False
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
# 0.9166666666666666 0.8333333333333334 True
# Max_Accuracy: 0.9166666666666666
# Accuracy: 0.9166666666666666
# 1.0 0.9166666666666666 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Lu Liu
# Number of edges:  411
# Number of nodes:  58
# Number of class:  17
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# M. Rahman
# Number of edges:  58
# Number of nodes:  17
# Number of class:  9
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Manuel Silva
# Number of edges:  1206
# Number of nodes:  74
# Number of class:  4
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Mark Davis
# Number of edges:  168
# Number of nodes:  24
# Number of class:  6
# 0.75 0 True
# Max_Accuracy: 0.75
# Accuracy: 0.75
# 0.75 0.75 False
# Max_Accuracy: 0.75
# Accuracy: 0.75
# 1.0 0.75 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Michael Lang
# Number of edges:  76
# Number of nodes:  17
# Number of class:  4
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Michael Siegel
# Number of edges:  959
# Number of nodes:  54
# Number of class:  6
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Michael Smith
# Number of edges:  120
# Number of nodes:  33
# Number of class:  19
# 0.6666666666666666 0 True
# Max_Accuracy: 0.6666666666666666
# Accuracy: 0.6666666666666666
# 1.0 0.6666666666666666 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Michael Wagner
# Number of edges:  469
# Number of nodes:  71
# Number of class:  14
# 0.8333333333333334 0 True
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
# 1.0 0.8333333333333334 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Ning Zhang
# Number of edges:  1132
# Number of nodes:  127
# Number of class:  33
# 0.7391304347826086 0 True
# Max_Accuracy: 0.7391304347826086
# Accuracy: 0.7391304347826086
# 0.6956521739130435 0.7391304347826086 False
# Max_Accuracy: 0.7391304347826086
# Accuracy: 0.6956521739130435
# 0.8260869565217391 0.7391304347826086 True
# Max_Accuracy: 0.8260869565217391
# Accuracy: 0.8260869565217391
# 0.7391304347826086 0.8260869565217391 False
# Max_Accuracy: 0.8260869565217391
# Accuracy: 0.7391304347826086
# 0.782608695652174 0.8260869565217391 False
# Max_Accuracy: 0.8260869565217391
# Accuracy: 0.782608695652174
#
#
#
# Paul Brown
# Number of edges:  145
# Number of nodes:  27
# Number of class:  8
# 0.75 0 True
# Max_Accuracy: 0.75
# Accuracy: 0.75
# 0.75 0.75 False
# Max_Accuracy: 0.75
# Accuracy: 0.75
# 0.5 0.75 False
# Max_Accuracy: 0.75
# Accuracy: 0.5
# 1.0 0.75 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Paul Wang
# Number of edges:  80
# Number of nodes:  16
# Number of class:  7
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Peter Phillips
# Number of edges:  65
# Number of nodes:  13
# Number of class:  3
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Philip J. Smith
# Number of edges:  249
# Number of nodes:  33
# Number of class:  3
# 0.8571428571428571 0 True
# Max_Accuracy: 0.8571428571428571
# Accuracy: 0.8571428571428571
# 0.8571428571428571 0.8571428571428571 False
# Max_Accuracy: 0.8571428571428571
# Accuracy: 0.8571428571428571
# 1.0 0.8571428571428571 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Ping Zhou
# Number of edges:  187
# Number of nodes:  36
# Number of class:  18
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Qiang shen
# Number of edges:  633
# Number of nodes:  70
# Number of class:  3
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# R. Balasubramanian
# Number of edges:  82
# Number of nodes:  20
# Number of class:  6
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# R. Cole
# Number of edges:  122
# Number of nodes:  22
# Number of class:  5
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# R. Ramesh
# Number of edges:  487
# Number of nodes:  46
# Number of class:  9
# 0.625 0 True
# Max_Accuracy: 0.625
# Accuracy: 0.625
# 0.875 0.625 True
# Max_Accuracy: 0.875
# Accuracy: 0.875
# 1.0 0.875 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Rafael Alonso
# Number of edges:  254
# Number of nodes:  40
# Number of class:  2
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Rakesh Kumar
# Number of edges:  2810
# Number of nodes:  96
# Number of class:  10
# 0.8823529411764706 0 True
# Max_Accuracy: 0.8823529411764706
# Accuracy: 0.8823529411764706
# 1.0 0.8823529411764706 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Richard Taylor
# Number of edges:  290
# Number of nodes:  35
# Number of class:  16
# 0.8 0 True
# Max_Accuracy: 0.8
# Accuracy: 0.8
# 0.4 0.8 False
# Max_Accuracy: 0.8
# Accuracy: 0.4
# 0.6 0.8 False
# Max_Accuracy: 0.8
# Accuracy: 0.6
# 0.8 0.8 False
# Max_Accuracy: 0.8
# Accuracy: 0.8
# 1.0 0.8 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Robert Allen
# Number of edges:  255
# Number of nodes:  24
# Number of class:  9
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Robert Schreiber
# Number of edges:  469
# Number of nodes:  58
# Number of class:  1
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# S. Huang
# Number of edges:  44
# Number of nodes:  16
# Number of class:  15
# sample error!
#
#
#
# Sanjay Jain
# Number of edges:  12224
# Number of nodes:  217
# Number of class:  5
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Satoshi Kobayashi
# Number of edges:  331
# Number of nodes:  38
# Number of class:  4
# 0.7142857142857143 0 True
# Max_Accuracy: 0.7142857142857143
# Accuracy: 0.7142857142857143
# 1.0 0.7142857142857143 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Shu lin
# Number of edges:  2932
# Number of nodes:  76
# Number of class:  2
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Steve King
# Number of edges:  183
# Number of nodes:  31
# Number of class:  4
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Thomas D. Taylor
# Number of edges:  12
# Number of nodes:  4
# Number of class:  3
# sample error!
#
#
#
# Thomas Hermann
# Number of edges:  407
# Number of nodes:  44
# Number of class:  8
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Thomas Meyer
# Number of edges:  185
# Number of nodes:  31
# Number of class:  7
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Thomas Tran
# Number of edges:  115
# Number of nodes:  15
# Number of class:  2
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Thomas Wolf
# Number of edges:  108
# Number of nodes:  33
# Number of class:  8
# 0.8333333333333334 0 True
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
# 0.8333333333333334 0.8333333333333334 False
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
# 0.5 0.8333333333333334 False
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.5
# 0.8333333333333334 0.8333333333333334 False
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
# 0.8333333333333334 0.8333333333333334 False
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
#
#
#
# Thomas Zimmermann
# Number of edges:  1274
# Number of nodes:  67
# Number of class:  2
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Wei Wang
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-309-64df9ec9fdb3> in <module>()
#       1 for name in names2:
#       2     print(name)
# ----> 3     domodel(name)
#       4     print("\n\n")
#
# <ipython-input-307-d2f67f7f989f> in domodel(filename)
#       6     title = ProcessData.Wipe_off_Punctuation(title)
#       7     title_vocab,title_split = ProcessData.Split_Title(title)
# ----> 8     title_one_hot,Max_Sequence_Len,vocab_size = ProcessData.One_hot_encoding(title_vocab,title_split)
#       9     title_one_hot_padding = ProcessData.Padding_One_hot(title_one_hot,Max_Sequence_Len)
#      10     author_vocab,authors_split = ProcessData.Split_Authors(authors)
#
# ~\Algorithm\gcn+seq\按联合作者分\ProcessData.py in One_hot_encoding(vocabulary, sequence)
#     120     sequence_encoded = []
#     121     Max_Sequence_Len = 0
# --> 122     vocab_size = max(integer_encoded) + 2 #留出一个0来做padding
#     123     #构建one-hot词表
#     124     for i in range(len(sequence)):
#
# ValueError: max() arg is an empty sequence

# %%
names3=['Wei Xu',
 'Wen Gao',
 'William H. Hsu',
 'X. Zhang',
 'Xiaoming Wang',
 'Xiaoyan Li',
 'Yan Tang',
 'Yang Wang',
 'Yang Yu',
 'Yi Deng',
 'Yong Chen',
 'Yoshio Tanaka',
 'Young Park',
 'Yu Zhang',
 'Yue Zhao',
 'Yun Wang',
 'Z. Wang']

# %%
for name in names3:
    print(name)
    domodel(name)
    print("\n\n")
# Out:
# Wei Xu
# Number of edges:  1835
# Number of nodes:  153
# Number of class:  48
# d:\Anaconda3\lib\site-packages\dgl\frame.py:204: UserWarning: Initializer is not set. Use zero initializer instead. To suppress this warning, use `set_initializer` to explicitly specify which initializer to use.
#   dgl_warning('Initializer is not set. Use zero initializer instead.'
# 0.7916666666666666 0 True
# Max_Accuracy: 0.7916666666666666
# Accuracy: 0.7916666666666666
# 0.6666666666666666 0.7916666666666666 False
# Max_Accuracy: 0.7916666666666666
# Accuracy: 0.6666666666666666
# 0.8333333333333334 0.7916666666666666 True
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
# 0.75 0.8333333333333334 False
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.75
# 0.6666666666666666 0.8333333333333334 False
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.6666666666666666
#
#
#
# Wen Gao
# Number of edges:  37470
# Number of nodes:  484
# Number of class:  10
# 0.968421052631579 0 True
# Max_Accuracy: 0.968421052631579
# Accuracy: 0.968421052631579
# 0.9789473684210527 0.968421052631579 True
# Max_Accuracy: 0.9789473684210527
# Accuracy: 0.9789473684210527
# 0.9789473684210527 0.9789473684210527 False
# Max_Accuracy: 0.9789473684210527
# Accuracy: 0.9789473684210527
# 0.968421052631579 0.9789473684210527 False
# Max_Accuracy: 0.9789473684210527
# Accuracy: 0.968421052631579
# 0.9894736842105263 0.9789473684210527 True
# Max_Accuracy: 0.9894736842105263
# Accuracy: 0.9894736842105263
#
#
#
# William H. Hsu
# Number of edges:  232
# Number of nodes:  34
# Number of class:  2
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# X. Zhang
# Number of edges:  217
# Number of nodes:  62
# Number of class:  40
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Xiaoming Wang
# Number of edges:  378
# Number of nodes:  38
# Number of class:  14
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Xiaoyan Li
# Number of edges:  262
# Number of nodes:  33
# Number of class:  6
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Yan Tang
# Number of edges:  237
# Number of nodes:  32
# Number of class:  11
# 0.8 0 True
# Max_Accuracy: 0.8
# Accuracy: 0.8
# 0.6 0.8 False
# Max_Accuracy: 0.8
# Accuracy: 0.6
# 0.8 0.8 False
# Max_Accuracy: 0.8
# Accuracy: 0.8
# 0.8 0.8 False
# Max_Accuracy: 0.8
# Accuracy: 0.8
# 0.8 0.8 False
# Max_Accuracy: 0.8
# Accuracy: 0.8
#
#
#
# Yang Wang
# Number of edges:  1315
# Number of nodes:  195
# Number of class:  55
# 0.6944444444444444 0 True
# Max_Accuracy: 0.6944444444444444
# Accuracy: 0.6944444444444444
# 0.6944444444444444 0.6944444444444444 False
# Max_Accuracy: 0.6944444444444444
# Accuracy: 0.6944444444444444
# 0.6111111111111112 0.6944444444444444 False
# Max_Accuracy: 0.6944444444444444
# Accuracy: 0.6111111111111112
# 0.7777777777777778 0.6944444444444444 True
# Max_Accuracy: 0.7777777777777778
# Accuracy: 0.7777777777777778
# 0.6111111111111112 0.7777777777777778 False
# Max_Accuracy: 0.7777777777777778
# Accuracy: 0.6111111111111112
#
#
#
# Yang Yu
# Number of edges:  625
# Number of nodes:  71
# Number of class:  19
# 0.9166666666666666 0 True
# Max_Accuracy: 0.9166666666666666
# Accuracy: 0.9166666666666666
# 0.9166666666666666 0.9166666666666666 False
# Max_Accuracy: 0.9166666666666666
# Accuracy: 0.9166666666666666
# 0.75 0.9166666666666666 False
# Max_Accuracy: 0.9166666666666666
# Accuracy: 0.75
# 0.8333333333333334 0.9166666666666666 False
# Max_Accuracy: 0.9166666666666666
# Accuracy: 0.8333333333333334
# 0.75 0.9166666666666666 False
# Max_Accuracy: 0.9166666666666666
# Accuracy: 0.75
#
#
#
# Yi Deng
# Number of edges:  1312
# Number of nodes:  89
# Number of class:  9
# 0.9411764705882353 0 True
# Max_Accuracy: 0.9411764705882353
# Accuracy: 0.9411764705882353
# 0.9411764705882353 0.9411764705882353 False
# Max_Accuracy: 0.9411764705882353
# Accuracy: 0.9411764705882353
# 0.8823529411764706 0.9411764705882353 False
# Max_Accuracy: 0.9411764705882353
# Accuracy: 0.8823529411764706
# 0.8823529411764706 0.9411764705882353 False
# Max_Accuracy: 0.9411764705882353
# Accuracy: 0.8823529411764706
# 1.0 0.9411764705882353 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Yong Chen
# Number of edges:  857
# Number of nodes:  84
# Number of class:  25
# 0.6923076923076923 0 True
# Max_Accuracy: 0.6923076923076923
# Accuracy: 0.6923076923076923
# 0.6923076923076923 0.6923076923076923 False
# Max_Accuracy: 0.6923076923076923
# Accuracy: 0.6923076923076923
# 0.9230769230769231 0.6923076923076923 True
# Max_Accuracy: 0.9230769230769231
# Accuracy: 0.9230769230769231
# 0.6923076923076923 0.9230769230769231 False
# Max_Accuracy: 0.9230769230769231
# Accuracy: 0.6923076923076923
# 0.9230769230769231 0.9230769230769231 False
# Max_Accuracy: 0.9230769230769231
# Accuracy: 0.9230769230769231
#
#
#
# Yoshio Tanaka
# Number of edges:  935
# Number of nodes:  43
# Number of class:  2
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Young Park
# Number of edges:  96
# Number of nodes:  21
# Number of class:  9
# 0.5 0 True
# Max_Accuracy: 0.5
# Accuracy: 0.5
# 0.5 0.5 False
# Max_Accuracy: 0.5
# Accuracy: 0.5
# 1.0 0.5 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Yu Zhang
# Number of edges:  1624
# Number of nodes:  235
# Number of class:  72
# 0.717948717948718 0 True
# Max_Accuracy: 0.717948717948718
# Accuracy: 0.717948717948718
# 0.7948717948717948 0.717948717948718 True
# Max_Accuracy: 0.7948717948717948
# Accuracy: 0.7948717948717948
# 0.7692307692307693 0.7948717948717948 False
# Max_Accuracy: 0.7948717948717948
# Accuracy: 0.7692307692307693
# 0.7948717948717948 0.7948717948717948 False
# Max_Accuracy: 0.7948717948717948
# Accuracy: 0.7948717948717948
# 0.7692307692307693 0.7948717948717948 False
# Max_Accuracy: 0.7948717948717948
# Accuracy: 0.7692307692307693
#
#
#
# Yue Zhao
# Number of edges:  453
# Number of nodes:  41
# Number of class:  9
# 0.8571428571428571 0 True
# Max_Accuracy: 0.8571428571428571
# Accuracy: 0.8571428571428571
# 0.8571428571428571 0.8571428571428571 False
# Max_Accuracy: 0.8571428571428571
# Accuracy: 0.8571428571428571
# 0.7142857142857143 0.8571428571428571 False
# Max_Accuracy: 0.8571428571428571
# Accuracy: 0.7142857142857143
# 1.0 0.8571428571428571 True
# Max_Accuracy: 1.0
# Accuracy: 1.0
#
#
#
# Yun Wang
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# d:\Anaconda3\lib\xml\sax\expatreader.py in feed(self, data, isFinal)
#     216             # except when invoked from close.
# --> 217             self._parser.Parse(data, isFinal)
#     218         except expat.error as e:
#
# ExpatError: no element found: line 227, column 0
#
# During handling of the above exception, another exception occurred:
#
# SAXParseException                         Traceback (most recent call last)
# <ipython-input-311-7b836328abba> in <module>()
#       1 for name in names3:
#       2     print(name)
# ----> 3     domodel(name)
#       4     print("\n\n")
#
# <ipython-input-307-d2f67f7f989f> in domodel(filename)
#       3     xml = filename + ".xml"
#       4     trace="Data\\"+filename+"\\"
# ----> 5     title,labels,jconf,authors,FullName,organization = ProcessData.ProcessingRawData(trace+xml)
#       6     title = ProcessData.Wipe_off_Punctuation(title)
#       7     title_vocab,title_split = ProcessData.Split_Title(title)
#
# ~\Algorithm\gcn+seq\按联合作者分\ProcessData.py in ProcessingRawData(FileName)
#     150     parser.setContentHandler( Handler )
#     151     #parser.parse("AjayGupta1.xml")
# --> 152     parser.parse(FileName)
#     153     labels = Handler.label.split("\n\t\t")
#     154     labels = list(map(int,labels[:-1]))
#
# d:\Anaconda3\lib\xml\sax\expatreader.py in parse(self, source)
#     109             self.reset()
#     110             self._cont_handler.setDocumentLocator(ExpatLocator(self))
# --> 111             xmlreader.IncrementalParser.parse(self, source)
#     112         except:
#     113             # bpo-30264: Close the source on error to not leak resources:
#
# d:\Anaconda3\lib\xml\sax\xmlreader.py in parse(self, source)
#     125             self.feed(buffer)
#     126             buffer = file.read(self._bufsize)
# --> 127         self.close()
#     128
#     129     def feed(self, data):
#
# d:\Anaconda3\lib\xml\sax\expatreader.py in close(self)
#     238             return
#     239         try:
# --> 240             self.feed("", isFinal = 1)
#     241             self._cont_handler.endDocument()
#     242             self._parsing = 0
#
# d:\Anaconda3\lib\xml\sax\expatreader.py in feed(self, data, isFinal)
#     219             exc = SAXParseException(expat.ErrorString(e.code), e, self)
#     220             # FIXME: when to invoke error()?
# --> 221             self._err_handler.fatalError(exc)
#     222
#     223     def _close_source(self):
#
# d:\Anaconda3\lib\xml\sax\handler.py in fatalError(self, exception)
#      36     def fatalError(self, exception):
#      37         "Handle a non-recoverable error."
# ---> 38         raise exception
#      39
#      40     def warning(self, exception):
#
# SAXParseException: Data\Yun Wang\Yun Wang.xml:227:0: no element found

# %%
names4=[ 'Yun Wang',
 'Z. Wang']

# %%
for name in names4:
    print(name)
    domodel(name)
    print("\n\n")
# Out:
# Yun Wang
# Number of edges:  180
# Number of nodes:  46
# Number of class:  19
# d:\Anaconda3\lib\site-packages\dgl\frame.py:204: UserWarning: Initializer is not set. Use zero initializer instead. To suppress this warning, use `set_initializer` to explicitly specify which initializer to use.
#   dgl_warning('Initializer is not set. Use zero initializer instead.'
# 0.6666666666666666 0 True
# Max_Accuracy: 0.6666666666666666
# Accuracy: 0.6666666666666666
# 0.8333333333333334 0.6666666666666666 True
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
# 0.8333333333333334 0.8333333333333334 False
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
# 0.8333333333333334 0.8333333333333334 False
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.8333333333333334
# 0.6666666666666666 0.8333333333333334 False
# Max_Accuracy: 0.8333333333333334
# Accuracy: 0.6666666666666666
#
#
#
# Z. Wang
# Number of edges:  127
# Number of nodes:  47
# Number of class:  38
# 1.0 0 True
# Max_Accuracy: 1.0
# Accuracy: 1.0

# %%
names5 = ["Barry Wilkinson","Eric Martin","Ping Zhou"]
names5 = ["Lei Fang","Paul Brown","Steve King"]
names5 = ["Eric Martin"]

# %%
for name in names5:
    print(name)
    domodel(name)
    print("\n\n")
# Out:
# Eric Martin
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-66bc60f32e4b> in <module>()
#       1 for name in names5:
#       2     print(name)
# ----> 3     domodel(name)
#       4     print("\n\n")
#
# NameError: name 'domodel' is not defined

# %%
model = GCN_Plus_RNN(RNN_input_size,
                     RNN_hidden_size,
                     RGCN_input_size,
                     RGCN_hidden_size,
                     Num_classes,
                     Num_rels,
                     Num_bases=-1,
                     Num_hidden_layers=0,
                     dropout=dropout)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=0)
criterion = nn.CrossEntropyLoss()

# %%
model.train()
for i in range(201):
    optimizer.zero_grad()
    output = model(g, inputs, sequence_length)
    loss = criterion(output[train_idx], labels_y[train_idx])
    loss.backward()
    optimizer.step()
    if i % 50 == 0:
        print(loss.data)
        print("Train Accuracy: ",Comput_Accuracy(train_idx))
        print("Validation Accuracy: ",Comput_Accuracy(test_idx))
# Out:
# d:\Anaconda3\lib\site-packages\dgl\frame.py:204: UserWarning: Initializer is not set. Use zero initializer instead. To suppress this warning, use `set_initializer` to explicitly specify which initializer to use.
#   dgl_warning('Initializer is not set. Use zero initializer instead.'
# tensor(5.5435)
# Train Accuracy:  0.011363636363636364
# Validation Accuracy:  0.015151515151515152
# tensor(0.3368)
# Train Accuracy:  0.9204545454545454
# Validation Accuracy:  0.8636363636363636
# tensor(0.0869)
# Train Accuracy:  0.9734848484848485
# Validation Accuracy:  0.9242424242424242
# tensor(0.0593)
# Train Accuracy:  0.9848484848484849
# Validation Accuracy:  0.9090909090909091
# tensor(0.0440)
# Train Accuracy:  0.9886363636363636
# Validation Accuracy:  0.9090909090909091
